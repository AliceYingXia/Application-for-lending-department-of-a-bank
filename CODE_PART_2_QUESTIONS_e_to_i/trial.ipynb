# %%
keywords = ['Consolidated Income Statements',
            'Consolidated Balance Sheets',
            'Consolidated Income Statement',
            'Consolidated Statement of Financial Position',
            'Income Statement',
            'Balance Sheet',
            'CONSOLIDATED BALANCE SHEETS',
            'CONSOLIDATED STATEMENTS OF INCOME',
            'CONSOLIDATED INCOME STATEMENT',
            'CONSOLIDATED BALANCE SHEET',
            'Consolidated balance sheets',
            'Consolidated statements of income',
            'CONSOLIDATED BALANCE SHEETS',
            'CONSOLIDATED STATEMENTS OF INCOME',
            'Consolidated Income Statements',
            'Consolidated Balance Sheets',
            'CONSOLIDATED STATEMENT OF INCOME',
            'CONSOLIDATED BALANCE SHEET' ]

# %%
keywords = [item.lower() for item in keywords]

# %%
keywords = set(keywords)
keywords = list(keywords)
keywords
# Out:
# ['consolidated statements of income',
#  'consolidated income statement',
#  'consolidated balance sheet',
#  'consolidated balance sheets',
#  'consolidated statement of income',
#  'consolidated income statements',
#  'balance sheet',
#  'income statement',
#  'consolidated statement of financial position']

# %%
income_keywords = ['consolidated statements of income',
 'consolidated income statement',
 'consolidated statement of income',
 'consolidated income statements',
 'income statement']
balance_keywords = ['consolidated balance sheet',
 'consolidated balance sheets',
 'balance sheet',
 'consolidated statement of financial position']

# %%
len('consolidated statement of financial position')
# Out:
# 44
